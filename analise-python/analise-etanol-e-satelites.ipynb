# %% [markdown]
# Usando a biblioteca Pandas em Python

# %%
import pandas as pd

# %% [markdown]
# Criando series com dados

# %%
pd.Series(data=5)
# Out:
# 0    5
# dtype: int64

# %%
nomes = 'Matheus Beatriz Giovanna Esther Terezinha Fábio'.split()

pd.Series(nomes)
# Out:
# 0      Matheus
# 1      Beatriz
# 2     Giovanna
# 3       Esther
# 4    Terezinha
# 5        Fábio
# dtype: object

# %%
dados = {
    'nome 1': 'Matheus',
    'nome 2': 'Beatriz',
    'nome 3': 'Giovanna',
    'nome 4': 'Esther',
    'nome 5': 'Teresinha',
    'nome 6': 'Fábio',
}
pd.Series(dados)
# Out:
# nome 1      Matheus
# nome 2      Beatriz
# nome 3     Giovanna
# nome 4       Esther
# nome 5    Teresinha
# nome 6        Fábio
# dtype: object

# %% [markdown]
# Rotulando as series, adicionando uma coluna ao data

# %%
nomes = 'Matheus Beatriz Giovanna Esther Terezinha Fábio'.split()
cpfs = '111.111.111-11 222.222.222-22 333.333.333-33 444.444.444-44 555.555.555-55 666.666.666-66'.split()

pd.Series(nomes, index=cpfs)
# Out:
# 111.111.111-11      Matheus
# 222.222.222-22      Beatriz
# 333.333.333-33     Giovanna
# 444.444.444-44       Esther
# 555.555.555-55    Terezinha
# 666.666.666-66        Fábio
# dtype: object

# %% [markdown]
# Localizando no data, a uma informação especifica através do rotulo

# %%
nomes = 'Matheus Beatriz Giovanna Esther Terezinha Fábio'.split()
cpfs = '111.111.111-11 222.222.222-22 333.333.333-33 444.444.444-44 555.555.555-55 666.666.666-66'.split()

series_dados = pd.Series(nomes, index=cpfs)

series_dados.loc['333.333.333-33']
# Out:
# 'Giovanna'

# %% [markdown]
# Extraindo informações de uma serie

# %%
series_dados = pd.Series([10.2, -1, None, 15, 23.4])

print('Quantidade de linhas = ', series_dados.shape) # Retorna uma tupla com o número de linhas
print('Tipo de dados =', series_dados.dtypes) # Retorna o tipo de dados, se for misto será object
print('Os valores são únicos? ', series_dados.is_unique) # Verifica se os valores são únicos (sem duplicações)
print('Existem valores nulos? ', series_dados.hasnans) # Verifica se existem valores nulos
print('Quantos valores existem? ', series_dados.count()) # Conta quantas valores existem (excluí os nulos)

print('Qual o menor valor? ', series_dados.min()) # Extrai o menor valor da Series (nesse caso os dados precisam ser do mesmo tipo)
print('Qual o maior valor? ', series_dados.max()) # Extrai o valor máximo, com a mesma condição do mínimo
print('Qual a média aritmética? ', series_dados.mean()) # Extrai a média aritmética de uma Series numérica
print('Qual o desvio padrão? ', series_dados.std()) # Extrai o desvio padrão de uma Series numérica
print('Qual a mediana?' , series_dados.median()) # Extrai a mediana de uma Series numérica

print('\nResumo:\n ', series_dados.describe()) # Exibe um resumo sobre os dados na Series
# Out:
# Quantidade de linhas =  (5,)
# Tipo de dados = float64
# Os valores são únicos?  True
# Existem valores nulos?  True
# Quantos valores existem?  4
# Qual o menor valor?  -1.0
# Qual o maior valor?  23.4
# Qual a média aritmética?  11.899999999999999
# Qual o desvio padrão?  10.184301645179211
# Qual a mediana? 12.6
#
# Resumo:
#   count     4.000000
# mean     11.900000
# std      10.184302
# min      -1.000000
# 25%       7.400000
# 50%      12.600000
# 75%      17.100000
# max      23.400000
# dtype: float64

# %% [markdown]
# Construindo um DataFrame com lista em python

# %%
nome = 'Matheus Beatriz Giovanna Esther Terezinha Fábio'.split()
cpf = '111.111.111-11 222.222.222-22 333.333.333-33 444.444.444-44 555.555.555-55 666.666.666-66'.split()
idade = [21, 21, 15, 9, 45, 55]

pd.DataFrame(nome, columns=['nome'])
pd.DataFrame(nome, columns=['nome'], index=cpf)

dados = list(zip(nome, cpf, idade))

pd.DataFrame(dados, columns=['Nome','Cpf','Idade'])
# Out:
#         Nome             Cpf  Idade
# 0    Matheus  111.111.111-11     21
# 1    Beatriz  222.222.222-22     21
# 2   Giovanna  333.333.333-33     15
# 3     Esther  444.444.444-44      9
# 4  Terezinha  555.555.555-55     45
# 5      Fábio  666.666.666-66     55

# %% [markdown]
# Construindo um DataFrame com dicionário em python

# %%
dados = {
    'nomes': 'Matheus Beatriz Giovanna Esther Terezinha Fábio'.split(),
    'cpfs': '111.111.111-11 222.222.222-22 333.333.333-33 444.444.444-44 555.555.555-55 666.666.666-66'.split(),
    'idades': [21, 21, 15, 9, 45, 55]
}

pd.DataFrame(dados)
# Out:
#        nomes            cpfs  idades
# 0    Matheus  111.111.111-11      21
# 1    Beatriz  222.222.222-22      21
# 2   Giovanna  333.333.333-33      15
# 3     Esther  444.444.444-44       9
# 4  Terezinha  555.555.555-55      45
# 5      Fábio  666.666.666-66      55

# %% [markdown]
# Extraindo informações de um DataFrame

# %%
dados = {
    'nomes': 'Matheus Beatriz Giovanna Esther Terezinha Fabio'.split(),
    'cpfs': '111.111.111-11 222.222.222-22 333.333.333-33 444.444.444-44 555.555.555-55 666.666.666-66'.split(),
    'idades': [21, 21, 15, 9, 45, 55]
}

df_dados = pd.DataFrame(dados)

print('\nInformações do DataFrame:\n')
print(df_dados.info()) # Apresenta informações sobre a estrutura do DF

print('\nQuantidade de linhas e colunas = ', df_dados.shape) # Retorna uma tupla com o número de linhas e colunas
print('\nTipo de dados:\n', df_dados.dtypes) # Retorna o tipo de dados, para cada coluna, se for misto será object

print('\nQual o menor valor de cada coluna?\n', df_dados.min()) # Extrai o menor de cada coluna
print('\nQual o maior valor?\n', df_dados.max()) # Extrai o valor máximo e cada coluna
#print('\nQual a média aritmética?\n', df_dados.mean()) # Extrai a média aritmética de cada coluna numérica
#print('\nQual o desvio padrão?\n', df_dados.std()) # Extrai o desvio padrão de cada coluna numérica
#print('\nQual a mediana?\n', df_dados.median()) # Extrai a mediana de cada coluna numérica

print('\nResumo:\n', df_dados.describe()) # Exibe um resumo

df_dados.head() # Exibe os 5 primeiros registros do DataFrame
# Out:
# Informações do DataFrame:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nomes   6 non-null      object
#  1   cpfs    6 non-null      object
#  2   idades  6 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 276.0+ bytes
# None
#
# Quantidade de linhas e colunas =  (6, 3)
#
# Tipo de dados:
#  nomes     object
# cpfs      object
# idades     int64
# dtype: object
#
# Qual o menor valor de cada coluna?
#  nomes            Beatriz
# cpfs      111.111.111-11
# idades                 9
# dtype: object
#
# Qual o maior valor?
#  nomes          Terezinha
# cpfs      666.666.666-66
# idades                55
# dtype: object
#
# Resumo:
#            idades
# count   6.000000
# mean   27.666667
# std    18.140195
# min     9.000000
# 25%    16.500000
# 50%    21.000000
# 75%    39.000000
# max    55.000000
# ...

# %% [markdown]
# Selecionando apenas uma coluna do DataFrame

# %%
df_uma_coluna = df_dados['idades']
print(type(df_uma_coluna))

print('Média de idades = ', df_uma_coluna.mean())

df_uma_coluna
# Out:
# <class 'pandas.core.series.Series'>
# Média de idades =  27.666666666666668
# 0    21
# 1    21
# 2    15
# 3     9
# 4    45
# 5    55
# Name: idades, dtype: int64

# %% [markdown]
# Selecionando duas colunas no DataFrame

# %%
colunas = ['nomes', 'cpfs']
df_duas_colunas = df_dados[colunas]
print(type(df_duas_colunas))
df_duas_colunas
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        nomes            cpfs
# 0    Matheus  111.111.111-11
# 1    Beatriz  222.222.222-22
# 2   Giovanna  333.333.333-33
# 3     Esther  444.444.444-44
# 4  Terezinha  555.555.555-55
# 5      Fabio  666.666.666-66

# %% [markdown]
# Acessando uma pagina de noticias do jornal New York Times usando a biblioteca do requestes.get()

# %%
import requests

texto = requests.get('https://www.nytimes.com/interactive/2017/06/23/opinion/trumps-lies.html').text
print(texto[:100])
# Out:
# <!DOCTYPE html>
# <!--[if (gt IE 9)|!(IE)]> <!--><html lang="en" class="no-js page-interactive section

# %% [markdown]
# Usando a biblioteca Beaufiful Soup com html 'html.parser' e find_all()

# %%
from bs4 import BeautifulSoup

textoB = BeautifulSoup(texto, 'html.parser')
listasnoticias = textoB.find_all('span', attrs={'class': 'short-desc'})

print(type(textoB))
print(type(listasnoticias))
print(listasnoticias[5])

listasnoticias[5].contents
# Out:
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.element.ResultSet'>
# <span class="short-desc"><strong>Jan. 25 </strong>“You had millions of people that now aren't insured anymore.” <span class="short-truth"><a href="https://www.nytimes.com/2017/03/13/us/politics/fact-check-trump-obamacare-health-care.html" target="_blank">(The real number is less than 1 million, according to the Urban Institute.)</a></span></span>
# [<strong>Jan. 25 </strong>,
#  "“You had millions of people that now aren't insured anymore.” ",
#  <span class="short-truth"><a href="https://www.nytimes.com/2017/03/13/us/politics/fact-check-trump-obamacare-health-care.html" target="_blank">(The real number is less than 1 million, according to the Urban Institute.)</a></span>]

# %% [markdown]
# Apendando na lista de dados uma tupla com as informações retiradas do site

# %%
dados = []

for noticia in listasnoticias:
  data = noticia.contents[0].text.strip() + ', 2017'
  comentario = noticia.contents[1].strip().replace("“", '').replace("”", '')
  explicacao = noticia.contents[2].text.strip().replace("(", '').replace(")", '')
  url = noticia.find('a')['href']
  dados.append((data,comentario,explicacao,url))

dados[1]
# Out:
# ('Jan. 21, 2017',
#  'A reporter for Time magazine — and I have been on their cover 14 or 15 times. I think we have the all-time record in the history of Time magazine.',
#  'Trump was on the cover 11 times and Nixon appeared 55 times.',
#  'http://nation.time.com/2013/11/06/10-things-you-didnt-know-about-time/')

# %% [markdown]
# Criando um DataFrame com base nas informações da tupla

# %%
df_noticias = pd.DataFrame(dados, columns=['data', 'comentario', 'explicação', 'url'])

print(df_noticias.shape)
print(df_noticias.dtypes)
df_noticias.head()
# Out:
# (180, 4)
# data          object
# comentario    object
# explicação    object
# url           object
# dtype: object
#             data                                         comentario  \
# 0  Jan. 21, 2017  I wasn't a fan of Iraq. I didn't want to go in...
# 1  Jan. 21, 2017  A reporter for Time magazine — and I have been...
# 2  Jan. 23, 2017  Between 3 million and 5 million illegal votes ...
# 3  Jan. 25, 2017  Now, the audience was the biggest ever. But th...
# 4  Jan. 25, 2017  Take a look at the Pew reports (which show vot...
#
#                                           explicação  \
# 0   He was for an invasion before he was against it.
# 1  Trump was on the cover 11 times and Nixon appe...
# 2             There's no evidence of illegal voting.
# 3  Official aerial photos show Obama's 2009 inaug...
# 4            The report never mentioned voter fraud.
#
#                                                  url
# 0  https://www.buzzfeed.com/andrewkaczynski/in-20...
# ...

# %% [markdown]
# Leitura de dados estruturados com a biblioteca pandas

# %%
url = 'https://www.fdic.gov/bank/individual/failed/banklist.html'
dfs = pd.read_html(url)

print(type(dfs))
print(len(dfs))
# Out:
# <class 'list'>
# 1

# %% [markdown]
# Acessando a tabela através da posição 0 do DataFrame

# %%
df_bancos = dfs[0]

print(df_bancos.shape)
print(df_bancos.dtypes)

df_bancos.head()
# Out:
# (25, 7)
# Bank Name                object
# City                     object
# State                    object
# Cert                      int64
# Acquiring Institution    object
# Closing Date             object
# Fund  Sort ascending      int64
# dtype: object
#                                Bank Name          City         State   Cert  \
# 0      Metropolitan Capital Bank & Trust       Chicago      Illinois  57488
# 1           The Santa Anna National Bank    Santa Anna         Texas   5520
# 2                   Pulaski Savings Bank       Chicago      Illinois  28611
# 3     The First National Bank of Lindsay       Lindsay      Oklahoma   4134
# 4  Republic First Bank dba Republic Bank  Philadelphia  Pennsylvania  27332
#
#                Acquiring Institution      Closing Date  Fund  Sort ascending
# 0            First Independence Bank  January 30, 2026                 10550
# 1          Coleman County State Bank     June 27, 2025                 10549
# ...

# %% [markdown]
# Ultilizando as bibliotecas requests, BeautifulSoup, bandas e datatime, oara fazer um wev scraping

# %%
from datetime import datetime

import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# Nesse código vou acessar o portal e utilizar a propriedade text da biblioteca requests para capturar em formato string

# %%
textoString = requests.get('https://globoesporte.globo.com/').text
horaExtracao = datetime.now().strftime('%d-%m-%Y %H:%M:%S')

bspTexto = BeautifulSoup(textoString, 'html.parser')
listaNoticias = bspTexto.find_all('div', attrs={'class':'feed-post-body'})
print("Quantidade de manchetes = ", len(listaNoticias))
listaNoticias[1].contents
# Out:
# Quantidade de manchetes =  7
# [<div class="feed-post-header with-post-chapeu"><span class="feed-post-header-chapeu">fisiculturismo</span></div>,
#  <div class="feed-post-body-title gui-color-primary gui-color-hover"><div class="_evt"><h2><a class="feed-post-link gui-color-primary gui-color-hover" href="https://ge.globo.com/fisiculturismo/noticia/2026/04/28/quem-e-o-criador-do-bordao-sabor-energetico-que-revelou-astros-do-fisiculturismo-como-dino-e-pantera.ghtml"><p elementtiming="text-ssr">Quem é o criador do bordão "sabor energético" que revelou astros como Ramon Dino e Rodrigo Pantera</p></a></h2></div></div>,
#  <div class="feed-post-body-resumo"><p elementtiming="text-ssr">Influenciador busca ampliar negócios patrocinando até times de futebol, como Ponte Preta e Portuguesa</p></div>,
# ...

# %%
listaNoticias[1].contents[1].text.replace('"', "")
# Out:
# 'Quem é o criador do bordão sabor energético que revelou astros como Ramon Dino e Rodrigo Pantera'

# %%
listaNoticias[1].find('a').get('href')
# Out:
# 'https://ge.globo.com/fisiculturismo/noticia/2026/04/28/quem-e-o-criador-do-bordao-sabor-energetico-que-revelou-astros-do-fisiculturismo-como-dino-e-pantera.ghtml'

# %%
descricao = listaNoticias[1].contents[2].text
if not descricao:
  descricao = noticia.find('div', attrs={'class': 'bstn-related'})
  descricao = descricao.text if descricao else None
descricao
# Out:
# 'Influenciador busca ampliar negócios patrocinando até times de futebol, como Ponte Preta e Portuguesa'

# %% [markdown]
# Extração da seção e do tempo decorrido

# %%
metadados = listaNoticias[2].find('div', attrs={'class':'feed-post-metadata'})

timeDelta = metadados.find('span', attrs={'class':'feed-post-datetime'})
secao = metadados.find('span', attrs={'class': 'feed-post-metadata-section'})

timeDelta = timeDelta.text if timeDelta else None
secao = secao.text if secao else None

print('timeDelta = ', timeDelta)
print('seção = ', secao)
# Out:
# timeDelta =  Há 1 hora
# seção =   fórmula 1

# %% [markdown]
# Criando um dataset, com uma estrutura de repetição e apendanda uma tupla com as informações extraidas

# %%
dados = []

for noticia in listaNoticias[1:]:
  manchete = noticia.contents[1].text.replace('"',"")
  link = noticia.find('a').get('href')

  descricao = noticia.contents[2].text
  if not descricao:
    descricao = noticia.find('div', 'bstn-related')
    descricao = descricao.text if descricao else None

  metadados = noticia.find('div', attrs={'class':'feed-post-metadata'})
  timeDelta = metadados.find('span', attrs={'class':'feed-post-datetime'})
  secao = metadados.find('span', attrs={'feed-post-metadata-section'})

  timeDelta = timeDelta.text if timeDelta else None
  secao = secao.text if secao else None

  dados.append((manchete, descricao, link, secao, horaExtracao, timeDelta))

df = pd.DataFrame(dados, columns=['manchete', 'descrição', 'link', 'seção', 'hora_extração', 'time_delta'])
df.head()
# Out:
#                                             manchete  \
# 0  Quem é o criador do bordão sabor energético qu...
# 1  F1 retorna de pausa forçada com mudanças dentr...
# 2  Resumo do dIA ge tem vitória de Bia Haddad e j...
# 3  Casemiro tem mais gols de cabeça do que nove c...
# 4  Praia Clube precisa quebrar jejum de mais de u...
#
#                                            descrição  \
# 0  Influenciador busca ampliar negócios patrocina...
# 1  Categoria ficou um mês sem atividades depois q...
# 2  Confira as principais notícias do esporte sele...
# 3  Em busca da Champions inédita, Kane se inspira...
# 4  Equipe de Uberlândia não venceu o maior rival ...
#
#                                                 link                    seção  \
# 0  https://ge.globo.com/fisiculturismo/noticia/20...          fisiculturismo
# 1  https://ge.globo.com/motor/formula-1/noticia/2...               fórmula 1
# 2  https://interativos.ge.globo.com/podcasts/prog...                     None
# ...

# %% [markdown]
# Leitura de json e csv com pandas

# %%
import pandas as pd

# %%
pd.read_json("https://api.bcb.gov.br/dados/serie/bcdata.sgs.11/dados?formato=json&dataInicial=20/04/2025").head()
# Out:
#          data     valor
# 0  22/04/2025  0.052531
# 1  23/04/2025  0.052531
# 2  24/04/2025  0.052531
# 3  25/04/2025  0.052531
# 4  28/04/2025  0.052531

# %%
pd.read_csv("https://people.sc.fsu.edu/~jburkardt/data/csv/cities.csv").head()
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State"
# 0        "Youngstown"       OH
# 1           "Yankton"       SD
# 2            "Yakima"       WA
# 3         "Worcester"       MA
# 4   "Wisconsin Dells"       WI

# %% [markdown]
# Capturando e transformando/padronizando dados

# %%
dfSelic = pd.read_json("https://api.bcb.gov.br/dados/serie/bcdata.sgs.11/dados?formato=json&dataInicial=20/04/2020")
print(dfSelic.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1509 entries, 0 to 1508
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    1509 non-null   object
#  1   valor   1509 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 23.7+ KB
# None

# %% [markdown]
# Removendo linhas duplicadas

# %%
dfSelic.drop_duplicates(keep='last', inplace=True)

# %% [markdown]
# Criando novas colunas

# %%
from datetime import date
from datetime import datetime as dt

dataExtracao = date.today()

dfSelic['data_extracao'] = dataExtracao
dfSelic['responsavel'] = "Autora"

print(dfSelic.info())
dfSelic.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1509 entries, 0 to 1508
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   data           1509 non-null   object
#  1   valor          1509 non-null   float64
#  2   data_extracao  1509 non-null   object
#  3   responsavel    1509 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 47.3+ KB
# None
#          data     valor data_extracao responsavel
# 0  20/04/2020  0.014227    2026-04-23      Autora
# 1  22/04/2020  0.014227    2026-04-23      Autora
# 2  23/04/2020  0.014227    2026-04-23      Autora
# 3  24/04/2020  0.014227    2026-04-23      Autora
# 4  27/04/2020  0.014227    2026-04-23      Autora

# %% [markdown]
# Método to_datetime() e astype()

# %%
dfSelic['data'] = pd.to_datetime(dfSelic['data'], dayfirst=True)
dfSelic['data_extracao'] = dfSelic['data_extracao'].astype('datetime64[ns]')

print(dfSelic.info())
dfSelic.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1509 entries, 0 to 1508
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   data           1509 non-null   datetime64[ns]
#  1   valor          1509 non-null   float64
#  2   data_extracao  1509 non-null   datetime64[ns]
#  3   responsavel    1509 non-null   object
# dtypes: datetime64[ns](2), float64(1), object(1)
# memory usage: 47.3+ KB
# None
#         data     valor data_extracao responsavel
# 0 2020-04-20  0.014227    2026-04-23      Autora
# 1 2020-04-22  0.014227    2026-04-23      Autora
# 2 2020-04-23  0.014227    2026-04-23      Autora
# 3 2020-04-24  0.014227    2026-04-23      Autora
# 4 2020-04-27  0.014227    2026-04-23      Autora

# %% [markdown]
# Usando o series.str

# %%
dfSelic['responsavel'] = dfSelic['responsavel'].str.upper()

dfSelic.head()
# Out:
#         data     valor data_extracao responsavel
# 0 2020-04-20  0.014227    2026-04-23      AUTORA
# 1 2020-04-22  0.014227    2026-04-23      AUTORA
# 2 2020-04-23  0.014227    2026-04-23      AUTORA
# 3 2020-04-24  0.014227    2026-04-23      AUTORA
# 4 2020-04-27  0.014227    2026-04-23      AUTORA

# %% [markdown]
# Usando sort_values()

# %%
dfSelic.sort_values(by='data', ascending=False, inplace=True)

dfSelic.head()
# Out:
#            data     valor data_extracao responsavel
# 1508 2026-04-23  0.054266    2026-04-23      AUTORA
# 1507 2026-04-22  0.054266    2026-04-23      AUTORA
# 1506 2026-04-20  0.054266    2026-04-23      AUTORA
# 1505 2026-04-17  0.054266    2026-04-23      AUTORA
# 1504 2026-04-16  0.054266    2026-04-23      AUTORA

# %% [markdown]
# Usando metodo reset_index() e set_index()

# %%
dfSelic.reset_index(drop=True, inplace=True)

dfSelic.head()
# Out:
#         data     valor data_extracao responsavel
# 0 2026-04-23  0.054266    2026-04-23      AUTORA
# 1 2026-04-22  0.054266    2026-04-23      AUTORA
# 2 2026-04-20  0.054266    2026-04-23      AUTORA
# 3 2026-04-17  0.054266    2026-04-23      AUTORA
# 4 2026-04-16  0.054266    2026-04-23      AUTORA

# %% [markdown]
# Definindo novos valores de indices com meu_df.set_index()

# %%
listaNovoIndice = [f' selic_{indice}' for indice in dfSelic.index]

print(listaNovoIndice[:5])
# Out:
# [' selic_0', ' selic_1', ' selic_2', ' selic_3', ' selic_4']

# %%
dfSelic.set_index(keys=[listaNovoIndice], inplace=True)

dfSelic.head()
# Out:
#               data     valor data_extracao responsavel
# selic_0 2026-04-23  0.054266    2026-04-23      AUTORA
# selic_1 2026-04-22  0.054266    2026-04-23      AUTORA
# selic_2 2026-04-20  0.054266    2026-04-23      AUTORA
# selic_3 2026-04-17  0.054266    2026-04-23      AUTORA
# selic_4 2026-04-16  0.054266    2026-04-23      AUTORA

# %% [markdown]
# Especificando os indices com idxmin() e idxmax()

# %%
print(dfSelic['valor'].idxmax())
print(dfSelic['valor'].idxmax())
# Out:
#  selic_24
#  selic_24

# %% [markdown]
# Realizando filtros com Loc

# %%
dfSelic.loc[' selic_0']
# Out:
# data             2026-04-23 00:00:00
# valor                       0.054266
# data_extracao    2026-04-23 00:00:00
# responsavel                   AUTORA
# Name:  selic_0, dtype: object

# %%
dfSelic.loc[[' selic_0',' selic_4',' selic_200']]
# Out:
#                 data     valor data_extracao responsavel
# selic_0   2026-04-23  0.054266    2026-04-23      AUTORA
# selic_4   2026-04-16  0.054266    2026-04-23      AUTORA
# selic_200 2025-07-08  0.055131    2026-04-23      AUTORA

# %%
dfSelic.loc[:' selic_5']
# Out:
#               data     valor data_extracao responsavel
# selic_0 2026-04-23  0.054266    2026-04-23      AUTORA
# selic_1 2026-04-22  0.054266    2026-04-23      AUTORA
# selic_2 2026-04-20  0.054266    2026-04-23      AUTORA
# selic_3 2026-04-17  0.054266    2026-04-23      AUTORA
# selic_4 2026-04-16  0.054266    2026-04-23      AUTORA
# selic_5 2026-04-15  0.054266    2026-04-23      AUTORA

# %% [markdown]
# Filtrando por coluna a busca pelo .loc

# %%
dfSelic.loc[[' selic_0', ' selic_4',' selic_200'], 'valor']
# Out:
# selic_0      0.054266
# selic_4      0.054266
# selic_200    0.055131
# Name: valor, dtype: float64

# %%
dfSelic.loc[[' selic_0',' selic_4', ' selic_200'], ['valor', 'data_extracao']]
# Out:
#               valor data_extracao
# selic_0    0.054266    2026-04-23
# selic_4    0.054266    2026-04-23
# selic_200  0.055131    2026-04-23

# %% [markdown]
# Criando filtros com .iloc

# %%
dfSelic.iloc[:5]
# Out:
#               data     valor data_extracao responsavel
# selic_0 2026-04-23  0.054266    2026-04-23      AUTORA
# selic_1 2026-04-22  0.054266    2026-04-23      AUTORA
# selic_2 2026-04-20  0.054266    2026-04-23      AUTORA
# selic_3 2026-04-17  0.054266    2026-04-23      AUTORA
# selic_4 2026-04-16  0.054266    2026-04-23      AUTORA

# %% [markdown]
# Filtros com testes booleanos, usando operadores relacionais com valores das colunas de um DF

# %%
teste = dfSelic['valor'] < 0.01

print(type(teste))
teste[:5]
# Out:
# <class 'pandas.core.series.Series'>
# selic_0    False
# selic_1    False
# selic_2    False
# selic_3    False
# selic_4    False
# Name: valor, dtype: bool

# %%
teste2 = dfSelic['data'] >= pd.to_datetime('2025-08-02')

print(type(teste2))
teste2[:5]
# Out:
# <class 'pandas.core.series.Series'>
# selic_0    True
# selic_1    True
# selic_2    True
# selic_3    True
# selic_4    True
# Name: data, dtype: bool

# %%
teste3 = (dfSelic['valor'] < 0.01) & (dfSelic['data'] >= pd.to_datetime('2025-08-02'))
teste4 = (dfSelic['valor'] < 0.01) | (dfSelic['data'] >= pd.to_datetime('2025-08-02'))

print("Resultado do AND: \n")
print(teste3[:3])

print("Resultado do OR: \n")
print(teste4[:3])
# Out:
# Resultado do AND:
#
# selic_0    False
# selic_1    False
# selic_2    False
# dtype: bool
# Resultado do OR:
#
# selic_0    True
# selic_1    True
# selic_2    True
# dtype: bool

# %%
filtro1 = dfSelic['valor'] < 0.01

dfSelic.loc[filtro1]
# Out:
#                  data     valor data_extracao responsavel
# selic_1281 2021-03-17  0.007469    2026-04-23      AUTORA
# selic_1282 2021-03-16  0.007469    2026-04-23      AUTORA
# selic_1283 2021-03-15  0.007469    2026-04-23      AUTORA
# selic_1284 2021-03-12  0.007469    2026-04-23      AUTORA
# selic_1285 2021-03-11  0.007469    2026-04-23      AUTORA
# ...               ...       ...           ...         ...
# selic_1464 2020-06-24  0.008442    2026-04-23      AUTORA
# selic_1465 2020-06-23  0.008442    2026-04-23      AUTORA
# selic_1466 2020-06-22  0.008442    2026-04-23      AUTORA
# selic_1467 2020-06-19  0.008442    2026-04-23      AUTORA
# selic_1468 2020-06-18  0.008442    2026-04-23      AUTORA
#
# [188 rows x 4 columns]

# %%
data1 = pd.to_datetime('2021-01-01')
data2 = pd.to_datetime('2021-01-31')

filtroJaneiro2021 = (dfSelic['data'] >= data1) & (dfSelic['data'] <= data2)

dfJaneiro2021 = dfSelic.loc[filtroJaneiro2021]
dfJaneiro2021.head()
# Out:
#                  data     valor data_extracao responsavel
# selic_1312 2021-01-29  0.007469    2026-04-23      AUTORA
# selic_1313 2021-01-28  0.007469    2026-04-23      AUTORA
# selic_1314 2021-01-27  0.007469    2026-04-23      AUTORA
# selic_1315 2021-01-26  0.007469    2026-04-23      AUTORA
# selic_1316 2021-01-25  0.007469    2026-04-23      AUTORA

# %% [markdown]
# Retirando informações da tabela para saber o máximo e o minimo e a médias dos meses janeiro de 2025 e 2026

# %%
data3 = pd.to_datetime('2025-01-01')
data4 = pd.to_datetime('2025-01-31')

data5 = pd.to_datetime('2026-01-01')
data6 = pd.to_datetime('2026-01-31')

filtroJaneiro2025 = (dfSelic['data'] >= data3) & (dfSelic['data'] <= data4)
filtroJaneiro2026 = (dfSelic['data'] >= data5) & (dfSelic['data'] <= data6)

dfJaneiro2025 = dfSelic.loc[filtroJaneiro2025]
dfJaneiro2026 = dfSelic.loc[filtroJaneiro2026]

print('Mínimo geral = ', dfSelic['valor'].min())
print('Mínimo janeiro de 2025 = ', dfJaneiro2025['valor'].min())
print('Mínimo janeiro de 2026 = ',dfJaneiro2026['valor'].min(), '\n')

print('Máximo geral = ', dfSelic['valor'].max())
print('Máximo janeiro de 2025 = ', dfJaneiro2025['valor'].max())
print('Máximo janeiro de 2026 = ',dfJaneiro2026['valor'].max(), '\n')

print('Média geral = ', dfSelic['valor'].mean())
print('Média janeiro de 2025 = ', dfJaneiro2025['valor'].mean())
print('Média janeiro de 2026 = ',dfJaneiro2026['valor'].mean(), '\n')
# Out:
# Mínimo geral =  0.007469
# Mínimo janeiro de 2025 =  0.045513
# Mínimo janeiro de 2026 =  0.055131
#
# Máximo geral =  0.055131
# Máximo janeiro de 2025 =  0.049037
# Máximo janeiro de 2026 =  0.055131
#
# Média geral =  0.03823826905235255
# Média janeiro de 2025 =  0.04583336363636364
# Média janeiro de 2026 =  0.055131000000000006

# %% [markdown]
# Salvando em CSV a tabela dfSelic

# %%
dfSelic.to_csv('dadosSelic.csv')

# %% [markdown]
# Analisando um arquivo .csv com pandas

# %%
import pandas as pd

dfEtanol = pd.read_csv('importacoes-exportacoes-etanol-2012-2025.csv', sep=';', encoding="ISO-8859-1")

print(dfEtanol.info())
dfEtanol.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ï»¿ANO               680 non-null    int64
#  1   MES                  680 non-null    object
#  2   PRODUTO              680 non-null    object
#  3   OPERACAO COMERCIAL   680 non-null    object
#  4   IMPORTADO/EXPORTADO  680 non-null    object
#  5   DISPENDIO/RECEITA    680 non-null    int64
#  6   Unnamed: 6           0 non-null      float64
#  7   Unnamed: 7           0 non-null      float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 42.6+ KB
# None
#    ï»¿ANO  MES        PRODUTO OPERACAO COMERCIAL IMPORTADO/EXPORTADO  \
# 0    2012  ABR  ETANOL ANIDRO       EXPORTAÃÃO           38397,357
# 1    2012  AGO  ETANOL ANIDRO       EXPORTAÃÃO          251088,364
#
#    DISPENDIO/RECEITA  Unnamed: 6  Unnamed: 7
# ...

# %% [markdown]
# Removendo colunas, para menor consumo de memória ram

# %%
dfEtanol.drop(columns=['PRODUTO', 'OPERACAO COMERCIAL','Unnamed: 6','Unnamed: 7' ], inplace=True)

dfEtanol.head(2)
# Out:
#    ï»¿ANO  MES IMPORTADO/EXPORTADO  DISPENDIO/RECEITA
# 0    2012  ABR           38397,357           29005781
# 1    2012  AGO          251088,364          179069921

# %% [markdown]
# Redefinindo o índice do DF, usando a coluna ano

# %%
dfEtanol.set_index(keys='ï»¿ANO', drop=True, inplace=True)

dfEtanol.head(2)
# Out:
#         MES IMPORTADO/EXPORTADO  DISPENDIO/RECEITA
# ï»¿ANO
# 2012    ABR           38397,357           29005781
# 2012    AGO          251088,364          179069921

# %% [markdown]
# Convertendo as virgulas em pontos, para se adequar ao padrão usada pela biblioteca pandas

# %%
for coluna in 'IMPORTADO/EXPORTADO'. split():
  dfEtanol[coluna] = dfEtanol[coluna].str.replace(',','.')

print(dfEtanol.dtypes)
dfEtanol.head(2)
# Out:
# MES                    object
# IMPORTADO/EXPORTADO    object
# DISPENDIO/RECEITA       int64
# dtype: object
#         MES IMPORTADO/EXPORTADO  DISPENDIO/RECEITA
# ï»¿ANO
# 2012    ABR           38397.357           29005781
# 2012    AGO          251088.364          179069921

# %% [markdown]
# Em cada ano, qual o menor e o maior valor arrecadado da exportação?

# %%
for ano in range(2012,2026):
  anoInfo = dfEtanol.loc[[ano], 'IMPORTADO/EXPORTADO']
  minimo = anoInfo.min()
  maximo = anoInfo.max()
  print(f"Ano = {ano}")
  print(f"Menor valor = {minimo}")
  print(f"Maior valor = {maximo}")
  print("---------------------------------")
# Out:
# Ano = 2012
# Menor valor = 10.764
# Maior valor = 99541.339
# ---------------------------------
# Ano = 2013
# Menor valor = 0.309
# Maior valor = 98.951
# ---------------------------------
# Ano = 2014
# Menor valor = 0.835
# Maior valor = 99217.171
# ---------------------------------
# Ano = 2015
# Menor valor = 0.387
# Maior valor = 9947.851
# ---------------------------------
# Ano = 2016
# Menor valor = 0.333
# Maior valor = 94266.978
# ---------------------------------
# Ano = 2017
# Menor valor = 0.296
# Maior valor = 94526.378
# ---------------------------------
# Ano = 2018
# Menor valor = 0.822
# Maior valor = 9247.978
# ---------------------------------
# Ano = 2019
# Menor valor = 0.214
# Maior valor = 98667.142
# ---------------------------------
# Ano = 2020
# Menor valor = 0.35
# Maior valor = 95960.517
# ---------------------------------
# Ano = 2021
# Menor valor = 0.567
# Maior valor = 95782.746
# ---------------------------------
# Ano = 2022
# Menor valor = 0.308
# ...

# %% [markdown]
# Considerando o período de 2012 a 2025, qual a média mensal de arrecadamento com a exportação

# %%
print("Média mensal de rendimentos:")
for mes_valor in dfEtanol['MES'].unique():
  media = dfEtanol.loc[dfEtanol['MES'] == mes_valor, 'IMPORTADO/EXPORTADO'].astype(float).mean()
  print(f"{mes_valor} = {media}")
# Out:
# Média mensal de rendimentos:
# ABR = 48782.26933928571
# AGO = 66941.76282142857
# DEZ = 62801.04810714286
# FEV = 49744.93958333333
# JAN = 59492.298449999995
# JUL = 64159.91237500001
# JUN = 54248.484625000005
# MAI = 45215.78151785714
# MAR = 59857.50842857143
# NOV = 51286.80132142857
# OUT = 66337.53525
# SET = 62658.40017857142

# %% [markdown]
# Considerando o período de 2012 a 2019, qual ano teve o menor arrecadamento? E o menor?

# %%
anoMenorArrecadacao = dfEtanol.loc[2012:2026, 'IMPORTADO/EXPORTADO'].idxmin()
anoMAiorArrecadacao = dfEtanol.loc[2012:2026, 'IMPORTADO/EXPORTADO'].idxmax()

print(f"Ano com menor arrecadação = {anoMenorArrecadacao}")
print(f"Ano com maior arrecadação = {anoMAiorArrecadacao}")
# Out:
# Ano com menor arrecadação = 2023
# Ano com maior arrecadação = 2012

# %% [markdown]
# Introdução a visualização de dados em Python

# %% [markdown]
# Usando a biblioteca matplotlib

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Gerando o meu primeiro gráfico em python

# %%
import random

dados1 = random.sample(range(100), k=20)
dados2 = random.sample(range(100), k=20)

plt.plot(dados1, dados2)

# %% [markdown]
# Figura com eixo como variável

# %%
import numpy as np

x = range(5)
x = np.array(x)

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

print("Tipo de ax = ", type(ax))
print("Conteúdo de ax[0] = ", ax[0])
print("Conteudo de ax[1] = ", ax[1])

ax[0].plot(x, x, label='eq_1')
ax[0].plot(x, x**2, label='eq_2')
ax[0].plot(x, x**3, label='eq_3')
ax[0].set_xlabel('Eixo x')
ax[0].set_ylabel('Eixo Y')
ax[0].set_title("Gráfico 1")
ax[0].legend()

ax[1].plot(x, x, 'r--', label='eq_1')
ax[1].plot(x**2, x, 'b--', label='eq_2')
ax[1].plot(x**3, x, 'g--', label='eq_3')
ax[1].set_xlabel('Novo Eixo x')
ax[1].set_ylabel('Novo Eixo y')
ax[1].set_title("Grafíco 2")
ax[1].legend()
# Out:
# Tipo de ax =  <class 'numpy.ndarray'>
# Conteúdo de ax[0] =  Axes(0.125,0.11;0.352273x0.77)
# Conteudo de ax[1] =  Axes(0.547727,0.11;0.352273x0.77)

# %% [markdown]
# Figura sem eixo como variável

# %%
x = range(5)
x = np.array(x)

fig = plt.subplots(figsize=(12, 5))
plt.subplot(121)
plt.plot(x, x, label='eq_1')
plt.plot(x, x**2, label='eq_2')
plt.plot(x, x**3, label='eq_3')
plt.title("Gráfico x")
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.legend()

plt.subplot(122)
plt.plot(x, x, 'r--', label='eq_1')
plt.plot(x**2, x, 'b--', label='eq_2')
plt.plot(x**3, x, 'g--', label='eq_3')
plt.title("Gráfico 2")
plt.xlabel('Novo eixo x')
plt.ylabel('Novo eixo y')
plt.legend()

# %% [markdown]
# Usando graficos com pandas

# %%
import pandas as pd

dados = {
    'turma':['A','B','C'],
    'qtdeAlunos':[33,50,45]
}
df = pd.DataFrame(dados)
df
# Out:
#   turma  qtdeAlunos
# 0     A          33
# 1     B          50
# 2     C          45

# %% [markdown]
# Criando o grafico com "df.plot(*args, **kwargs)", com o tipo de gráfico "kind='bar'"

# %%
df.plot(x='turma', y='qtdeAlunos', kind='bar')
# Out:
# <Axes: xlabel='turma'>

# %% [markdown]
# Criando o grafico com "df.plot(*args, **kwargs)", com o tipo de gráfico "kind='barh'"

# %%
df.plot(x='turma', y='qtdeAlunos', kind='barh')
# Out:
# <Axes: ylabel='turma'>

# %% [markdown]
# Criando o grafico com "df.plot(*args, **kwargs)", com o tipo de gráfico "kind='line'"

# %%
df.plot(x='turma', y='qtdeAlunos', kind='line')
# Out:
# <Axes: xlabel='turma'>

# %% [markdown]
# Criando o grafico com "df.plot(*args, **kwargs)", com o tipo de gráfico "kind='pie'"

# %%
df.set_index('turma').plot(y='qtdeAlunos', kind='pie')
# Out:
# <Axes: ylabel='qtdeAlunos'>

# %% [markdown]
# Outra fora de exibir os graficos

# %%
df.plot.bar(x='turma', y='qtdeAlunos')
df.plot.line(x='turma', y='qtdeAlunos')
df.set_index('turma').plot.pie(y='qtdeAlunos')
# Out:
# <Axes: ylabel='qtdeAlunos'>

# %% [markdown]
# Montando graficos a partir do arquivo .cs-v "importacoes-exportacoes-etanol-2012-2025"

# %%
import pandas as pd

dfEtanol = pd.read_csv('importacoes-exportacoes-etanol-2012-2025.csv', sep=';', encoding="ISO-8859-1")

#Apaga as colunas que não serão usadas
dfEtanol.drop(columns=['PRODUTO', 'OPERACAO COMERCIAL','Unnamed: 6','Unnamed: 7' ], inplace=True)

#Substitui a vírgula por ponto em cada coluna
for coluna in 'IMPORTADO/EXPORTADO'. split():
  dfEtanol[coluna] = dfEtanol[coluna].str.replace(',','.')

#Converte os valores para float
dfEtanol['IMPORTADO/EXPORTADO'] = dfEtanol['IMPORTADO/EXPORTADO'].astype(float)

#Converte o ano para inteiro
dfEtanol['ï»¿ANO'] = dfEtanol['ï»¿ANO'].astype(int)

dfEtanol.head(5)
# Out:
#    ï»¿ANO  MES  IMPORTADO/EXPORTADO  DISPENDIO/RECEITA
# 0    2012  ABR            38397.357           29005781
# 1    2012  AGO           251088.364          179069921
# 2    2012  DEZ           249441.640          163571473
# 3    2012  FEV            43042.930           36375709
# 4    2012  JAN            42469.904           38608035

# %%
dfEtanol.head(10).plot(x='ï»¿ANO',
              y='IMPORTADO/EXPORTADO',
              kind='bar',
              figsize=(10, 5),
              rot=0,
              fontsize=12,
              legend=False)
dfEtanol.plot(x='ï»¿ANO',
              y='IMPORTADO/EXPORTADO',
              kind='line',
              figsize=(10,5),
              rot=0,
              fontsize=12,
              legend=False)
# Out:
# <Axes: xlabel='ï»¿ANO'>

# %% [markdown]
# Comparando os meses

# %%
df_jan = dfEtanol[dfEtanol['MES'] == 'JAN'][['ï»¿ANO', 'IMPORTADO/EXPORTADO']]
df_feb = dfEtanol[dfEtanol['MES'] == 'FEV'][['ï»¿ANO', 'IMPORTADO/EXPORTADO']]

df_jan = df_jan.rename(columns={'IMPORTADO/EXPORTADO': 'IMPORTADO/EXPORTADO_JAN'})
df_feb = df_feb.rename(columns={'IMPORTADO/EXPORTADO': 'IMPORTADO/EXPORTADO_FEV'})


df_merged = pd.merge(df_jan, df_feb, on='ï»¿ANO', how='outer')

df_merged.plot(x='ï»¿ANO', y=['IMPORTADO/EXPORTADO_JAN', 'IMPORTADO/EXPORTADO_FEV'],
               kind='bar',
               figsize=(15, 7),
               rot=45,
               fontsize=12,
               title='Comparação de Exportação de Etanol por Ano (Janeiro vs Fevereiro)',
               xlabel='Ano',
               ylabel='Valor Importado/Exportado')

plt.tight_layout()
plt.show()

# %% [markdown]
# Biblioteca seaborn

# %%
import seaborn as sns

sns.set(style='whitegrid')

dfTips = sns.load_dataset('tips')

print(dfTips.info())
dfTips.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Função barplot()

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))

sns.barplot(data=dfTips, x='sex', y='total_bill', ax=ax[0])
sns.barplot(data=dfTips, x='sex', y='total_bill', ax=ax[1], estimator=sum)
sns.barplot(data=dfTips, x='sex', y='total_bill', ax=ax[2], estimator=len)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
plt.figure(figsize=(10,5))

ax = sns.barplot(x="day", y="total_bill", data=dfTips)

ax.axes.set_title("Venda média diária", fontsize=14)
ax.set_xlabel("Dia", fontsize=14)
ax.set_ylabel("Venda média ", fontsize=14)
ax.tick_params(labelsize=14)

# %% [markdown]
# Função countplot()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=dfTips, x="day")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# Usando o parâmetro "hue", para plotar a quantidade de pessoa por dia

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=dfTips, x="day", hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# Função scartterplot()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=dfTips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Geração de gráficos a partir de um arquivo csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfSatelites = pd.read_csv('satelites_operando_comercialmente.csv', sep=';')
dfSatelites.drop_duplicates(inplace=True)
dfSatelites.reset_index(drop=True, inplace=True)

print(dfSatelites.info())
dfSatelites.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Satélite em operação     56 non-null     object
#  1   Posição orbital          56 non-null     object
#  2   Bandas do satélite       56 non-null     object
#  3   Tipo de Direito          56 non-null     object
#  4   Operadora comercial      56 non-null     object
#  5   Posição Orbital Decimal  56 non-null     object
# dtypes: object(6)
# memory usage: 2.8+ KB
# None
#   Satélite em operação Posição orbital  \
# 0              ANIK G1         107,3ºO
# 1        INMARSAT-4 F3            98ºO
# 2        INMARSAT-4 F3            98ºO
# 3        INMARSAT-4 F3            98ºO
# 4            JUPITER 3          95,2ºO
#
#                        Bandas do satélite Tipo de Direito  \
# 0  C (não planejada),Ku (não planejada),X     Estrangeiro
# ...

# %% [markdown]
# Quantos satélites são brasileiros e quantos são estrangeiro?

# %%
plt.figure(figsize=(5,3))
plt.tick_params(labelsize=12)
sns.countplot(data=dfSatelites, x='Tipo de Direito')
# Out:
# <Axes: xlabel='Tipo de Direito', ylabel='count'>

# %% [markdown]
# quantos satétiles cada operadora brasileira possui operando?

# %%
dfSatelitesBrasileiros = dfSatelites.loc[dfSatelites['Tipo de Direito'] == 'Brasileiro']

plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
sns.countplot(data=dfSatelitesBrasileiros, x='Operadora comercial')
# Out:
# <Axes: xlabel='Operadora comercial', ylabel='count'>

# %% [markdown]
# Quantos satélites brasileiros estão operando em cada banda?

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
sns.countplot(data=dfSatelitesBrasileiros, x='Bandas do satélite')
# Out:
# <Axes: xlabel='Bandas do satélite', ylabel='count'>

# %% [markdown]
# Quantos satétiles cada operadora estrangeira possui operando?

# %%
dfSatelitesEstrangeiros =dfSatelites.loc[dfSatelites['Tipo de Direito'] == 'Estrangeiro']

plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
sns.countplot(data=dfSatelitesEstrangeiros, x='Operadora comercial')
# Out:
# <Axes: xlabel='Operadora comercial', ylabel='count'>

# %% [markdown]
# Quantos satélites brasileiros estão operando em cada banda?

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
sns.countplot(data=dfSatelitesEstrangeiros, x='Bandas do satélite')
# Out:
# <Axes: xlabel='Bandas do satélite', ylabel='count'>
